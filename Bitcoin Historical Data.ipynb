# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\mvenk\Downloads\archive\btcusd_1-min_data.csv",low_memory=False)
df
# Out:
#             Timestamp      Open      High       Low     Close    Volume  \
# 0        1.325412e+09      4.58      4.58      4.58      4.58  0.000000
# 1        1.325412e+09      4.58      4.58      4.58      4.58  0.000000
# 2        1.325412e+09      4.58      4.58      4.58      4.58  0.000000
# 3        1.325412e+09      4.58      4.58      4.58      4.58  0.000000
# 4        1.325412e+09      4.58      4.58      4.58      4.58  0.000000
# ...               ...       ...       ...       ...       ...       ...
# 6983808  1.744510e+09  85180.00  85180.00  85179.00  85179.00  0.011466
# 6983809  1.744510e+09  85179.00  85222.00  85179.00  85205.00  0.214465
# 6983810  1.744510e+09  85198.00  85198.00  85150.00  85166.00  0.085221
# 6983811  1.744510e+09  85164.00  85175.00  85164.00  85171.00  0.024468
# 6983812  1.744510e+09  85167.00  85174.00  85165.00  85169.00  0.158530
#
#                           datetime
# 0        2012-01-01 10:01:00+00:00
# ...

# %%
df.head()
# Out:
#       Timestamp  Open  High   Low  Close  Volume                   datetime
# 0  1.325412e+09  4.58  4.58  4.58   4.58     0.0  2012-01-01 10:01:00+00:00
# 1  1.325412e+09  4.58  4.58  4.58   4.58     0.0  2012-01-01 10:02:00+00:00
# 2  1.325412e+09  4.58  4.58  4.58   4.58     0.0  2012-01-01 10:03:00+00:00
# 3  1.325412e+09  4.58  4.58  4.58   4.58     0.0  2012-01-01 10:04:00+00:00
# 4  1.325412e+09  4.58  4.58  4.58   4.58     0.0  2012-01-01 10:05:00+00:00

# %%
df.tail()
# Out:
#             Timestamp     Open     High      Low    Close    Volume datetime
# 6983808  1.744510e+09  85180.0  85180.0  85179.0  85179.0  0.011466      NaN
# 6983809  1.744510e+09  85179.0  85222.0  85179.0  85205.0  0.214465      NaN
# 6983810  1.744510e+09  85198.0  85198.0  85150.0  85166.0  0.085221      NaN
# 6983811  1.744510e+09  85164.0  85175.0  85164.0  85171.0  0.024468      NaN
# 6983812  1.744510e+09  85167.0  85174.0  85165.0  85169.0  0.158530      NaN

# %%
df.dtypes
# Out:
# Timestamp    float64
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume       float64
# datetime      object
# dtype: object

# %%
df.isnull()
# Out:
#          Timestamp   Open   High    Low  Close  Volume  datetime
# 0            False  False  False  False  False   False     False
# 1            False  False  False  False  False   False     False
# 2            False  False  False  False  False   False     False
# 3            False  False  False  False  False   False     False
# 4            False  False  False  False  False   False     False
# ...            ...    ...    ...    ...    ...     ...       ...
# 6983808      False  False  False  False  False   False      True
# 6983809      False  False  False  False  False   False      True
# 6983810      False  False  False  False  False   False      True
# 6983811      False  False  False  False  False   False      True
# 6983812      False  False  False  False  False   False      True
#
# [6983813 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Timestamp         0
# Open              0
# High              0
# Low               0
# Close             0
# Volume            0
# datetime     201533
# dtype: int64

# %%
print((df.isnull().sum()/len(df))*100)
# Out:
# Timestamp    0.000000
# Open         0.000000
# High         0.000000
# Low          0.000000
# Close        0.000000
# Volume       0.000000
# datetime     2.885716
# dtype: float64

# %%
df['datetime']
# Out:
# 0          2012-01-01 10:01:00+00:00
# 1          2012-01-01 10:02:00+00:00
# 2          2012-01-01 10:03:00+00:00
# 3          2012-01-01 10:04:00+00:00
# 4          2012-01-01 10:05:00+00:00
#                      ...
# 6983808                          NaN
# 6983809                          NaN
# 6983810                          NaN
# 6983811                          NaN
# 6983812                          NaN
# Name: datetime, Length: 6983813, dtype: object

# %%
df['datetime'] = pd.to_datetime(df['datetime'], errors='coerce')
df['datetime'] =df['datetime'].astype("object")

# %%
df['datetime'] = df['datetime'].fillna('0000-00-00 00:00:00+00:00')

# %%
df.tail()
# Out:
#             Timestamp     Open     High      Low    Close    Volume  \
# 6983808  1.744510e+09  85180.0  85180.0  85179.0  85179.0  0.011466
# 6983809  1.744510e+09  85179.0  85222.0  85179.0  85205.0  0.214465
# 6983810  1.744510e+09  85198.0  85198.0  85150.0  85166.0  0.085221
# 6983811  1.744510e+09  85164.0  85175.0  85164.0  85171.0  0.024468
# 6983812  1.744510e+09  85167.0  85174.0  85165.0  85169.0  0.158530
#
#                           datetime
# 6983808  0000-00-00 00:00:00+00:00
# 6983809  0000-00-00 00:00:00+00:00
# 6983810  0000-00-00 00:00:00+00:00
# 6983811  0000-00-00 00:00:00+00:00
# 6983812  0000-00-00 00:00:00+00:00

# %%
df['datetime'] = pd.to_datetime(df['datetime'],errors= "coerce")

# %%
df['datetime'].dtype
# Out:
# datetime64[ns, UTC]

# %%
df['datetime']
# Out:
# 0         2012-01-01 10:01:00+00:00
# 1         2012-01-01 10:02:00+00:00
# 2         2012-01-01 10:03:00+00:00
# 3         2012-01-01 10:04:00+00:00
# 4         2012-01-01 10:05:00+00:00
#                      ...
# 6983808                         NaT
# 6983809                         NaT
# 6983810                         NaT
# 6983811                         NaT
# 6983812                         NaT
# Name: datetime, Length: 6983813, dtype: datetime64[ns, UTC]

# %%
df['datetime'].isna()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 6983808     True
# 6983809     True
# 6983810     True
# 6983811     True
# 6983812     True
# Name: datetime, Length: 6983813, dtype: bool

# %%
df['datetime'].dtype
# Out:
# datetime64[ns, UTC]

# %%
df.loc[df['datetime'].isna(), 'datetime'] = pd.to_datetime(df.loc[df['datetime'].isna(), 'Timestamp'], unit='s', utc=True)

# %%
print(df['datetime'].isna().sum())  # should print 0
print(df[['Timestamp', 'datetime']].tail())  # final rows now have filled datetime
# Out:
# 0
#             Timestamp                  datetime
# 6983808  1.744510e+09 2025-04-13 02:09:00+00:00
# 6983809  1.744510e+09 2025-04-13 02:10:00+00:00
# 6983810  1.744510e+09 2025-04-13 02:11:00+00:00
# 6983811  1.744510e+09 2025-04-13 02:12:00+00:00
# 6983812  1.744510e+09 2025-04-13 02:13:00+00:00

# %%
df
# Out:
#             Timestamp      Open      High       Low     Close    Volume  \
# 0        1.325412e+09      4.58      4.58      4.58      4.58  0.000000
# 1        1.325412e+09      4.58      4.58      4.58      4.58  0.000000
# 2        1.325412e+09      4.58      4.58      4.58      4.58  0.000000
# 3        1.325412e+09      4.58      4.58      4.58      4.58  0.000000
# 4        1.325412e+09      4.58      4.58      4.58      4.58  0.000000
# ...               ...       ...       ...       ...       ...       ...
# 6983808  1.744510e+09  85180.00  85180.00  85179.00  85179.00  0.011466
# 6983809  1.744510e+09  85179.00  85222.00  85179.00  85205.00  0.214465
# 6983810  1.744510e+09  85198.00  85198.00  85150.00  85166.00  0.085221
# 6983811  1.744510e+09  85164.00  85175.00  85164.00  85171.00  0.024468
# 6983812  1.744510e+09  85167.00  85174.00  85165.00  85169.00  0.158530
#
#                          datetime
# 0       2012-01-01 10:01:00+00:00
# ...

# %%
df['date'] = df['datetime'].dt.date

# %%
df['time'] = df['datetime'].dt.time

# %%
df
# Out:
#             Timestamp      Open      High       Low     Close    Volume  \
# 0        1.325412e+09      4.58      4.58      4.58      4.58  0.000000
# 1        1.325412e+09      4.58      4.58      4.58      4.58  0.000000
# 2        1.325412e+09      4.58      4.58      4.58      4.58  0.000000
# 3        1.325412e+09      4.58      4.58      4.58      4.58  0.000000
# 4        1.325412e+09      4.58      4.58      4.58      4.58  0.000000
# ...               ...       ...       ...       ...       ...       ...
# 6983808  1.744510e+09  85180.00  85180.00  85179.00  85179.00  0.011466
# 6983809  1.744510e+09  85179.00  85222.00  85179.00  85205.00  0.214465
# 6983810  1.744510e+09  85198.00  85198.00  85150.00  85166.00  0.085221
# 6983811  1.744510e+09  85164.00  85175.00  85164.00  85171.00  0.024468
# 6983812  1.744510e+09  85167.00  85174.00  85165.00  85169.00  0.158530
#
#                          datetime        date      time
# ...

# %%
df.drop(columns=['datetime'],inplace=True)

# %%
df
# Out:
#             Timestamp      Open      High       Low     Close    Volume  \
# 0        1.325412e+09      4.58      4.58      4.58      4.58  0.000000
# 1        1.325412e+09      4.58      4.58      4.58      4.58  0.000000
# 2        1.325412e+09      4.58      4.58      4.58      4.58  0.000000
# 3        1.325412e+09      4.58      4.58      4.58      4.58  0.000000
# 4        1.325412e+09      4.58      4.58      4.58      4.58  0.000000
# ...               ...       ...       ...       ...       ...       ...
# 6983808  1.744510e+09  85180.00  85180.00  85179.00  85179.00  0.011466
# 6983809  1.744510e+09  85179.00  85222.00  85179.00  85205.00  0.214465
# 6983810  1.744510e+09  85198.00  85198.00  85150.00  85166.00  0.085221
# 6983811  1.744510e+09  85164.00  85175.00  85164.00  85171.00  0.024468
# 6983812  1.744510e+09  85167.00  85174.00  85165.00  85169.00  0.158530
#
#                date      time
# 0        2012-01-01  10:01:00
# 1        2012-01-01  10:02:00
# ...

# %%
import pandas as pd
import datetime

# Ensure they're converted properly
df['date'] = pd.to_datetime(df['date']).dt.date  # Python datetime.date
df['time'] = pd.to_datetime(df['time'], format='%H:%M:%S').dt.time  # Python datetime.time

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6983813 entries, 0 to 6983812
# Data columns (total 8 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   Timestamp  float64
#  1   Open       float64
#  2   High       float64
#  3   Low        float64
#  4   Close      float64
#  5   Volume     float64
#  6   date       object
#  7   time       object
# dtypes: float64(6), object(2)
# memory usage: 426.3+ MB

# %%
df.dtypes
# Out:
# Timestamp    float64
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume       float64
# date          object
# time          object
# dtype: object

# %%
print(type(df['date'].iloc[0])) 
print(type(df['time'].iloc[0]))
# Out:
# <class 'datetime.date'>
# <class 'datetime.time'>

# %%
df.columns
# Out:
# Index(['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume', 'date', 'time'], dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#       Timestamp  Open  High   Low  Close  Volume        date      time
# 0  1.325412e+09  4.58  4.58  4.58   4.58     0.0  2012-01-01  10:01:00
# 1  1.325412e+09  4.58  4.58  4.58   4.58     0.0  2012-01-01  10:02:00
# 2  1.325412e+09  4.58  4.58  4.58   4.58     0.0  2012-01-01  10:03:00
# 3  1.325412e+09  4.58  4.58  4.58   4.58     0.0  2012-01-01  10:04:00
# 4  1.325412e+09  4.58  4.58  4.58   4.58     0.0  2012-01-01  10:05:00

# %% [markdown]
# # eda

# %%
plt.figure(figsize=(15,5))
plt.plot(df['Close'], label='Close Price', color='blue')
plt.title('BTC/USD Close Price Over Time')
plt.xlabel('Datetime')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(df['Volume'], label="Volume", color='orange')
plt.title("BTC/USD Volume Over Time")
plt.xlabel("Datetime")
plt.ylabel("Volume")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # with volume

# %%
df['SMA_50'] = df['Close'].rolling(window=50).mean()
df['SMA_200'] = df['Close'].rolling(window=200).mean()
plt.figure(figsize=(15,5))
plt.plot(df['Close'], label = 'Close', alpha=0.5)
plt.plot(df['SMA_50'], label = 'SMA 50', color = 'green')
plt.plot(df['SMA_200'], label='SMA 200',color = 'red')
plt.title("BTC/USD Close Price with SMA 50 & 200")
plt.xlabel("Datetime")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.show()

# %%
columns_to_plot = ['Open', 'High', 'Low', 'Close', 'Volume']

for col in columns_to_plot:
    plt.figure(figsize=(14, 5))
    plt.scatter(df.index, df[col], s=1)
    plt.title(f'{col} Over Time')
    plt.xlabel('Datetime')
    plt.ylabel(col)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Group by

# %%
grouped = df.groupby('date')[["Open", 'High','Low', 'Close', 'Volume']].mean()


grouped.sort_index(inplace=True)


for col in grouped.columns: 
    plt.figure(figsize=(14,5))
    plt.scatter(grouped.index, grouped[col], s=5)
    plt.title(f'Daily Average {col} Over Time')
    plt.xlabel("Date")
    plt.ylabel(col)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
grouped = df.groupby('date')[["Open", 'High','Low', 'Close', 'Volume']].sum()


grouped.sort_index(inplace=True)


for col in grouped.columns: 
    plt.figure(figsize=(14,5))
    plt.scatter(grouped.index, grouped[col], s=5)
    plt.title(f'Daily Sum {col} Over Time')
    plt.xlabel("Date")
    plt.ylabel(col)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
grouped = df.groupby('date')[["Open", 'High','Low', 'Close', 'Volume']].max()


grouped.sort_index(inplace=True)


for col in grouped.columns: 
    plt.figure(figsize=(14,5))
    plt.scatter(grouped.index, grouped[col], s=5)
    plt.title(f'Daily max {col} Over Time')
    plt.xlabel("Date")
    plt.ylabel(col)
    plt.grid(True)
    plt.tight_layout()
    plt.show()
